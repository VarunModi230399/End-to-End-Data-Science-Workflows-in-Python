# %% [markdown]
# ## Asynchronous scraping

# %%
pip install aiohttp
# Out:
# Requirement already satisfied: aiohttp in c:\users\d5dr2b7\appdata\local\programs\python\python313\lib\site-packages (3.12.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\d5dr2b7\appdata\local\programs\python\python313\lib\site-packages (from aiohttp) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\d5dr2b7\appdata\local\programs\python\python313\lib\site-packages (from aiohttp) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\d5dr2b7\appdata\local\programs\python\python313\lib\site-packages (from aiohttp) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\d5dr2b7\appdata\local\programs\python\python313\lib\site-packages (from aiohttp) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\d5dr2b7\appdata\local\programs\python\python313\lib\site-packages (from aiohttp) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\d5dr2b7\appdata\local\programs\python\python313\lib\site-packages (from aiohttp) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\d5dr2b7\appdata\local\programs\python\python313\lib\site-packages (from aiohttp) (1.20.1)
# Requirement already satisfied: idna>=2.0 in c:\users\d5dr2b7\appdata\local\programs\python\python313\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp) (3.10)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install asyncio
# Out:
# Collecting asyncio
#   Downloading asyncio-4.0.0-py3-none-any.whl.metadata (994 bytes)
# Downloading asyncio-4.0.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: asyncio
# Successfully installed asyncio-4.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import csv
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import aiohttp
#       2 import asyncio
# ----> 3 from bs4 import BeautifulSoup
#       4 import csv
#       5 import re
#
# ModuleNotFoundError: No module named 'bs4'

# %%
# !pip install nest-asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest-asyncio in /home/codespace/.local/lib/python3.10/site-packages (1.5.8)

# %%
async def scrap_and_save_links(text):
  soup = BeautifulSoup(text, 'html.parser')
  file = open('csv_file', 'a', newline='')
  writer= csv.writer(file, delimiter=',')
  for link in soup.findAll('a', attrs={'href': re.compile('^http')}):
    link = link.get('href')
    writer.writerow([link])
  file.close()

# %%
async def fetch(session, url):
   try:
      async with session.get(url) as response:
         text= await response.text()
         task = asyncio.create_task(scrap_and_save_links(text))
         await task
   except Exception as e:
      print(str(e))

# %%
async def scrap(urls):
  tasks = []
  async with aiohttp.ClientSession() as session:
    for url in urls:
      tasks.append(fetch(session,url))
    await asyncio.gather(*tasks)

# %%
urls = ['https://analytics.usa.gov/', 'https://www.python.org/', 'https://www.linkedin.com/']
asyncio.run(scrap(urls=urls))
